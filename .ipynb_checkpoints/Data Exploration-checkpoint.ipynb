# %% [markdown]
# ## Dataset Adopted from [this](https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/wdbc.data) link

# %% [markdown]
# An explanation of the dataset and overall idea as mentioned [here](https://www.inertia7.com/projects/3)

# %% [markdown]
# ### Preliminary Info about the data -
#
# The data set contains descriptive attributes of digitized images of a process known as, fine needle aspirate (FNA) of breast mass. We have a total of 29 features that were computed for each cell nucleus with an ID Number and the Diagnosis (Later converted to binary representations: Malignant = 1, Benign = 0).

# %% [markdown]
# ## Importing modules

# %%
# %matplotlib inline

import numpy as np
import pandas as pd # Data frames
import matplotlib.pyplot as plt # Visuals
import seaborn as sns # Danker visuals
from extraFunctions import *
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import KFold, cross_val_score 
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.tree import DecisionTreeClassifier 
from sklearn.tree import export_graphviz 
from sklearn.ensemble import RandomForestClassifier 
from sklearn.neural_network import MLPClassifier 
from sklearn.metrics import roc_curve # ROC Curves
from sklearn.metrics import auc # Calculating AUC for ROC's!
from urllib.request import urlopen
from sklearn.decomposition import PCA

pd.set_option('display.max_columns', 500) 
# Included to show all the columns 
# since it is a fairly large data set

plt.style.use('ggplot') # Using ggplot2 style visuals 
# because that's how I learned my visuals 
# and I'm sticking to it!

# %% [markdown]
# ## Import Data

# %%
data_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/wdbc.data'

columns = ['id_number', 'diagnosis', 'radius_mean', 
         'texture_mean', 'perimeter_mean', 'area_mean', 
         'smoothness_mean', 'compactness_mean', 'concavity_mean',
         'concave_points_mean', 'symmetry_mean', 
         'fractal_dimension_mean', 'radius_se', 'texture_se', 
         'perimeter_se', 'area_se', 'smoothness_se', 
         'compactness_se', 'concavity_se', 'concave_points_se', 
         'symmetry_se', 'fractal_dimension_se', 
         'radius_worst', 'texture_worst', 'perimeter_worst',
         'area_worst', 'smoothness_worst', 
         'compactness_worst', 'concavity_worst', 
         'concave_points_worst', 'symmetry_worst', 
         'fractal_dimension_worst'] 

df = pd.read_csv(urlopen(data_url),names=columns)
df.set_index(['id_number'],inplace=True)

#For CART models later
namesInd = columns[2:]

# %%
print("Dimensions: ", df.shape)
print("\nDataTypes:\n",df.dtypes)
# Out:
# Dimensions:  (569, 31)
#
# DataTypes:
#  diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave_points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave_points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# ...

# %% [markdown]
# ### We have 30 float features and one diagnosis column which is categorical.
#
# We can convert diagnosis to binary. Let's see.

# %%
df.diagnosis.value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# This does not just tell us about the names, but also tells that our data has a balanced amount of both the classes. Let's define a function to check imbalance. It is stored in the separate file - extraFunctions.py

# %%
class_balance(df.diagnosis) #imported from extraFunctions
# Out:
# 1) B - 63 %
# 2) M - 37 %

# %% [markdown]
# ### Convert to binary

# %%
mapper = {'B':0,'M':1}

df['diagnosis'] = df['diagnosis'].map(mapper)
#class_balance(df.diagnosis)

# %% [markdown]
# ## Exploration

# %%
df.describe()
# Out:
#         diagnosis  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  569.000000   569.000000    569.000000      569.000000   569.000000
# mean     0.372583    14.127292     19.289649       91.969033   654.889104
# std      0.483918     3.524049      4.301036       24.298981   351.914129
# min      0.000000     6.981000      9.710000       43.790000   143.500000
# 25%      0.000000    11.700000     16.170000       75.170000   420.300000
# 50%      0.000000    13.370000     18.840000       86.240000   551.100000
# 75%      1.000000    15.780000     21.800000      104.100000   782.700000
# max      1.000000    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
#Scatterplot

# Scatterplot Matrix
# Variables chosen from Random Forest modeling.
cols = ['concave_points_worst', 'concavity_mean', 
        'perimeter_worst', 'radius_worst', 
        'area_worst','diagnosis']

sns.pairplot(df,
             x_vars = cols,
             y_vars = cols,
             hue = 'diagnosis',
            markers=["o", "D"])

# %% [markdown]
# ## Correlation Matrix
#
# We will visualize a full correlation heatmap to see if we need dimensionality reduction. (I'm going to do it anyway)

# %%
corr = df.corr()

f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(100, 500, as_cmap=True)


# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr,cmap = cmap,square=True, 
            xticklabels=True, yticklabels=True,
            linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)

# %% [markdown]
# There's some correlation. Let's try
#
# ## Dimensionality Reduction

# %%
pca = PCA(copy=True, n_components=2, whiten=False)
#fir
pca.fit(df)

#transform
pca_df = pca.transform(df)

pca_df = pd.DataFrame(pca_df)
pca_df.index = df.index
pca_df.columns = ['PC1','PC2']
pca_df.head()
# Out:
#                    PC1         PC2
# id_number
# 842302     1160.142744 -293.917535
# 842517     1269.122597   15.630194
# 84300903    995.794082   39.156723
# 84348301   -407.180411  -67.380505
# 84358402    930.341382  189.340710

# %%
transformed = pca.transform(df)

print(pca.explained_variance_ratio_)
#plt.plot(pca.explained_variance_ratio_)
# Out:
# [ 0.98204444  0.01617648]

# %% [markdown]
# #### We will use df as well as pca_df to compare results

# %% [markdown]
# ## Normalization

# %%
f, ax = plt.subplots(figsize=(11, 15))
ax.set(xlim=(-.05, 50))

plt.ylabel('Dependent Variables')
plt.title("Box Plot of Pre-Processed Data Set")
ax = sns.boxplot(data = df, 
  orient = 'h')

# %% [markdown]
# Yup, we need to normalize

# %%
f, ax = plt.subplots(figsize=(11, 15))

plt.ylabel('Dependent Variables')
plt.title("Box Plot of Pre-Processed Data Set")
ax = sns.boxplot(data = pca_df, 
  orient = 'h')
